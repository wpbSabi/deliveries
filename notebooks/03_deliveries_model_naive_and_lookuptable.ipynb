# %%
from sklearn.ensemble import RandomForestRegressor
import os
import numpy as np
import pandas as pd
import sys
sys.path.append(os.path.dirname(os.getcwd()))
import functions

# %% [markdown]
# Data wrangling for the input data to models

# %%
# df = pd.read_csv('../data/features_table.csv', 
#                  parse_dates=['order_date'])
df = pd.read_parquet('../data/features_table.parquet')

# add an order_number to each row in df, in order of the order_date
df['order_number'] = df['order_date'].rank(method='first').astype(int)

# Do one-hot encoding first, so that the train and test columns match
features_data = functions.one_hot_encode(df, ['origin_country', 'us_destination_state'])

# %%
features_data.reset_index(drop=True).tail()
# Out:
#      projected_days  actual_days order_date  order_number  \
# 752               4            6 2018-02-04           753
# 753               4            5 2018-02-04           754
# 754               4            6 2018-02-05           755
# 755               4            6 2018-02-05           756
# 756               2            6 2018-02-06           757
#
#      origin_country_Vietnam  us_destination_state_AR  us_destination_state_AZ  \
# 752                    True                    False                    False
# 753                    True                    False                    False
# 754                    True                    False                    False
# 755                    True                    False                    False
# 756                    True                    False                    False
#
#      us_destination_state_CA  us_destination_state_CO  \
# 752                    False                    False
# 753                    False                    False
# 754                    False                    False
# 755                    False                    False
# 756                    False                    False
#
#      us_destination_state_CT  ...  us_destination_state_OH  \
# 752                    False  ...                    False
# 753                     True  ...                    False
# 754                    False  ...                    False
# 755                    False  ...                    False
# 756                    False  ...                    False
#
#      us_destination_state_OR  us_destination_state_PA  \
# 752                    False                    False
# 753                    False                    False
# 754                    False                    False
# 755                    False                    False
# 756                    False                    False
#
#      us_destination_state_PR  us_destination_state_SC  \
# 752                    False                    False
# 753                    False                    False
# 754                     True                    False
# 755                    False                    False
# 756                     True                    False
#
#      us_destination_state_TN  us_destination_state_TX  \
# 752                    False                     True
# 753                    False                    False
# 754                    False                    False
# 755                    False                    False
# 756                    False                    False
#
#      us_destination_state_UT  us_destination_state_VA  us_destination_state_WI
# 752                    False                    False                    False
# 753                    False                    False                    False
# 754                    False                    False                    False
# 755                    False                    False                    False
# 756                    False                    False                    False
#
# [5 rows x 38 columns]

# %%
# Choose the run_date for the train-test split
run_date = features_data['order_date'].quantile(0.9)
print(run_date)
# The window of dates will be one week
print(run_date + pd.Timedelta(days=7))
# Out:
# 2017-12-26 00:00:00
# 2018-01-02 00:00:00

# %% [markdown]
# Naive model
# * Uses the latest observation to predict the next (week's) observation(s)

# %%
# Training data to include all data up to the run_date, 
# and testing data to include all data from the run_date to one week after the run_date
# Unlike the machine learning model, there is no one-hot encoding and the order_date is retained
a_train1 = df[df['order_date'] < run_date]
a_test1 = df[df['order_date'] >= run_date]
a_test = a_test1[a_test1['order_date'] <= run_date + pd.Timedelta(days=7)]

# %%
# Filter a_train to only include the latest order_date for each origin_country and us_destination_state combination
a_train = a_train1.sort_values('order_date').groupby(['origin_country', 'us_destination_state']).tail(1).reset_index(drop=True)
# a_train.sort_values('order_date')
a_train.sort_values('us_destination_state')
# Out:
#    origin_country us_destination_state  projected_days  actual_days  \
# 12        Vietnam                   AR               4            4
# 23        Vietnam                   AZ               1            2
# 30        Vietnam                   CA               1            2
# 16        Vietnam                   CO               4            5
# 4         Vietnam                   CT               1            2
# 21        Vietnam                   DC               1            2
# 26        Vietnam                   FL               4            6
# 13        Vietnam                   GA               4            4
# 5         Vietnam                   HI               4            4
# 1         Vietnam                   ID               1            2
# 28        Vietnam                   IL               4            2
# 0         Vietnam                   KY               4            5
# 19        Vietnam                   LA               4            5
# 10        Vietnam                   MA               4            2
# 9         Vietnam                   MD               4            4
# 25        Vietnam                   MI               4            3
# 11        Vietnam                   MN               2            3
# 15        Vietnam                   MO               4            6
# 22        Vietnam                   NC               2            6
# 14        Vietnam                   NJ               4            6
# 2         Vietnam                   NV               4            3
# 18        Vietnam                   NY               4            2
# 24        Vietnam                   OH               4            6
# 8         Vietnam                   OR               4            6
# 27        Vietnam                   PA               1            2
# 29        Vietnam                   PR               2            6
# 6         Vietnam                   SC               2            2
# 3         Vietnam                   TN               4            4
# 31        Vietnam                   TX               4            3
# 7         Vietnam                   UT               1            2
# 20        Vietnam                   VA               4            6
# 17        Vietnam                   WI               4            6
#
#    order_date  order_number
# 12 2016-02-19           470
# 23 2017-12-05           655
# 30 2017-12-25           676
# 16 2016-03-08           559
# 4  2016-01-12           244
# 21 2017-11-20           647
# 26 2017-12-13           668
# 13 2016-02-21           482
# 5  2016-01-17           272
# 1  2015-10-31            21
# 28 2017-12-24           675
# 0  2015-10-29            11
# 19 2016-03-22           631
# 10 2016-02-01           385
# 9  2016-01-28           377
# 25 2017-12-10           663
# 11 2016-02-04           408
# 15 2016-03-04           543
# 22 2017-12-04           654
# 14 2016-02-26           526
# 2  2015-12-08           108
# 18 2016-03-19           605
# 24 2017-12-09           660
# 8  2016-01-26           369
# 27 2017-12-20           671
# 29 2017-12-25           679
# 6  2016-01-22           313
# 3  2015-12-10           121
# 31 2017-12-25           680
# 7  2016-01-24           344
# 20 2016-03-22           632
# 17 2016-03-16           592

# %%
# # To verify logic of choosing the latest order_date in the training set, could alternatively write a unit test
# print(run_date)
# # df[df['us_destination_state']=='AR']
# df[df['us_destination_state']=='AZ'].sort_values('order_date')

# %%
actuals = a_test[['origin_country', 'us_destination_state', 'order_date', 'order_number', 'actual_days']].reset_index(drop=True)
actuals
# Out:
#    origin_country us_destination_state order_date  order_number  actual_days
# 0         Vietnam                   PR 2017-12-26           681            4
# 1         Vietnam                   PR 2017-12-26           682            3
# 2         Vietnam                   CA 2017-12-26           683            2
# 3         Vietnam                   PR 2017-12-27           684            4
# 4         Vietnam                   PR 2017-12-27           685            3
# 5         Vietnam                   OH 2017-12-28           686            6
# 6         Vietnam                   MD 2017-12-28           687            4
# 7         Vietnam                   OH 2017-12-28           688            4
# 8         Vietnam                   OH 2017-12-29           689            5
# 9         Vietnam                   MO 2017-12-29           690            5
# 10        Vietnam                   PR 2017-12-30           691            6
# 11        Vietnam                   NJ 2017-12-30           692            4
# 12        Vietnam                   PR 2017-12-30           693            6
# 13        Vietnam                   PR 2017-12-31           694            2
# 14        Vietnam                   SC 2017-12-31           695            3
# 15        Vietnam                   PR 2018-01-01           696            4
# 16        Vietnam                   CO 2018-01-02           697            2
# 17        Vietnam                   PR 2018-01-02           698            5
# 18        Vietnam                   FL 2018-01-02           699            4

# %%
# add the predicted_days columne to naive, and fill it with the actual_days for each origin_country and us_destination_state combination in a_train
naive = actuals.copy()
naive['predicted_days'] = naive.apply(lambda row: a_train[(a_train['origin_country'] == row['origin_country']) & (a_train['us_destination_state'] == row['us_destination_state'])]['actual_days'].iloc[-1] if not a_train[(a_train['origin_country'] == row['origin_country']) & (a_train['us_destination_state'] == row['us_destination_state'])].empty else None, axis=1)

# if naive['predicted_days'] is null, remove those rows from the data, we can handle those with a different method (master table) later
naive = naive.dropna(subset=['predicted_days']).reset_index(drop=True)
# naive['predicted_days'] = naive['predicted_days'].fillna(a_train['actual_days'].mean())
naive
# Out:
#    origin_country us_destination_state order_date  order_number  actual_days  \
# 0         Vietnam                   PR 2017-12-26           681            4
# 1         Vietnam                   PR 2017-12-26           682            3
# 2         Vietnam                   CA 2017-12-26           683            2
# 3         Vietnam                   PR 2017-12-27           684            4
# 4         Vietnam                   PR 2017-12-27           685            3
# 5         Vietnam                   OH 2017-12-28           686            6
# 6         Vietnam                   MD 2017-12-28           687            4
# 7         Vietnam                   OH 2017-12-28           688            4
# 8         Vietnam                   OH 2017-12-29           689            5
# 9         Vietnam                   MO 2017-12-29           690            5
# 10        Vietnam                   PR 2017-12-30           691            6
# 11        Vietnam                   NJ 2017-12-30           692            4
# 12        Vietnam                   PR 2017-12-30           693            6
# 13        Vietnam                   PR 2017-12-31           694            2
# 14        Vietnam                   SC 2017-12-31           695            3
# 15        Vietnam                   PR 2018-01-01           696            4
# 16        Vietnam                   CO 2018-01-02           697            2
# 17        Vietnam                   PR 2018-01-02           698            5
# 18        Vietnam                   FL 2018-01-02           699            4
#
#     predicted_days
# 0                6
# 1                6
# 2                2
# 3                6
# 4                6
# 5                6
# 6                4
# 7                6
# 8                6
# 9                6
# 10               6
# 11               6
# 12               6
# 13               6
# 14               2
# 15               6
# 16               5
# 17               6
# 18               6

# %%
# Check for nan values in the predicted_days column, can be moved to a unit test later
print(naive['predicted_days'].isna().sum())
print(naive['actual_days'].unique())
print(naive['predicted_days'].unique())
# Out:
# 0
# [4 3 2 6 5]
# [6 2 4 5]

# %%
naive
# Out:
#    origin_country us_destination_state order_date  order_number  actual_days  \
# 0         Vietnam                   PR 2017-12-26           681            4
# 1         Vietnam                   PR 2017-12-26           682            3
# 2         Vietnam                   CA 2017-12-26           683            2
# 3         Vietnam                   PR 2017-12-27           684            4
# 4         Vietnam                   PR 2017-12-27           685            3
# 5         Vietnam                   OH 2017-12-28           686            6
# 6         Vietnam                   MD 2017-12-28           687            4
# 7         Vietnam                   OH 2017-12-28           688            4
# 8         Vietnam                   OH 2017-12-29           689            5
# 9         Vietnam                   MO 2017-12-29           690            5
# 10        Vietnam                   PR 2017-12-30           691            6
# 11        Vietnam                   NJ 2017-12-30           692            4
# 12        Vietnam                   PR 2017-12-30           693            6
# 13        Vietnam                   PR 2017-12-31           694            2
# 14        Vietnam                   SC 2017-12-31           695            3
# 15        Vietnam                   PR 2018-01-01           696            4
# 16        Vietnam                   CO 2018-01-02           697            2
# 17        Vietnam                   PR 2018-01-02           698            5
# 18        Vietnam                   FL 2018-01-02           699            4
#
#     predicted_days
# 0                6
# 1                6
# 2                2
# 3                6
# 4                6
# 5                6
# 6                4
# 7                6
# 8                6
# 9                6
# 10               6
# 11               6
# 12               6
# 13               6
# 14               2
# 15               6
# 16               5
# 17               6
# 18               6

# %%
# Calculate summary metrics
n_results, n_mape = functions.summarize_results(naive, 
                                        run_date, 
                                        y_test=naive['actual_days'], 
                                        y_pred=naive['predicted_days'],
                                        model_name='Naive',
                                        window_days=7)
print('Unique Origin-Destination pairs:',len(n_results[['origin_country', 'us_destination_state']].drop_duplicates()))
n_results
# Out:
# Predicted rows: 19
#  MAE: 1.526
#  RMSE: 1.933
#  R2: -1.367
#  MAPE: 0.496
# Unique Origin-Destination pairs: 9
#    origin_country us_destination_state order_date  order_number  actual  pred  \
# 0         Vietnam                   PR 2017-12-26           681       4     6
# 1         Vietnam                   PR 2017-12-26           682       3     6
# 2         Vietnam                   CA 2017-12-26           683       2     2
# 3         Vietnam                   PR 2017-12-27           684       4     6
# 4         Vietnam                   PR 2017-12-27           685       3     6
# 5         Vietnam                   OH 2017-12-28           686       6     6
# 6         Vietnam                   MD 2017-12-28           687       4     4
# 7         Vietnam                   OH 2017-12-28           688       4     6
# 8         Vietnam                   OH 2017-12-29           689       5     6
# 9         Vietnam                   MO 2017-12-29           690       5     6
# 10        Vietnam                   PR 2017-12-30           691       6     6
# 11        Vietnam                   NJ 2017-12-30           692       4     6
# 12        Vietnam                   PR 2017-12-30           693       6     6
# 13        Vietnam                   PR 2017-12-31           694       2     6
# 14        Vietnam                   SC 2017-12-31           695       3     2
# 15        Vietnam                   PR 2018-01-01           696       4     6
# 16        Vietnam                   CO 2018-01-02           697       2     5
# 17        Vietnam                   PR 2018-01-02           698       5     6
# 18        Vietnam                   FL 2018-01-02           699       4     6
#
#     abs_err  model
# 0         2  Naive
# 1         3  Naive
# 2         0  Naive
# 3         2  Naive
# 4         3  Naive
# 5         0  Naive
# 6         0  Naive
# 7         2  Naive
# 8         1  Naive
# 9         1  Naive
# 10        0  Naive
# 11        2  Naive
# 12        0  Naive
# 13        4  Naive
# 14        1  Naive
# 15        2  Naive
# 16        3  Naive
# 17        1  Naive
# 18        2  Naive

# %%
# Which rows in particular increased the MAE and RMSE the most? Show the top 10 rows with the highest absolute error between actual and predicted days, along with their origin_country and us_destination_state.
naive['abs_error'] = (naive['actual_days'] - naive['predicted_days']).abs()
naive.sort_values('abs_error', ascending=False)[['origin_country', 'us_destination_state', 'actual_days', 'predicted_days', 'abs_error']]
# Out:
#    origin_country us_destination_state  actual_days  predicted_days  abs_error
# 13        Vietnam                   PR            2               6          4
# 4         Vietnam                   PR            3               6          3
# 1         Vietnam                   PR            3               6          3
# 16        Vietnam                   CO            2               5          3
# 0         Vietnam                   PR            4               6          2
# 11        Vietnam                   NJ            4               6          2
# 3         Vietnam                   PR            4               6          2
# 7         Vietnam                   OH            4               6          2
# 15        Vietnam                   PR            4               6          2
# 18        Vietnam                   FL            4               6          2
# 8         Vietnam                   OH            5               6          1
# 17        Vietnam                   PR            5               6          1
# 14        Vietnam                   SC            3               2          1
# 9         Vietnam                   MO            5               6          1
# 2         Vietnam                   CA            2               2          0
# 10        Vietnam                   PR            6               6          0
# 6         Vietnam                   MD            4               4          0
# 5         Vietnam                   OH            6               6          0
# 12        Vietnam                   PR            6               6          0

# %%
# PR did have the most recent actual value of 6
df[df['us_destination_state'] == 'PR'].sort_values('order_date', ascending=False)[['origin_country', 'us_destination_state', 'order_date', 'actual_days']]
# Out:
#     origin_country us_destination_state order_date  actual_days
# 756        Vietnam                   PR 2018-02-06            6
# 754        Vietnam                   PR 2018-02-05            6
# 748        Vietnam                   PR 2018-02-02            6
# 740        Vietnam                   PR 2018-01-30            2
# 737        Vietnam                   PR 2018-01-29            2
# ..             ...                  ...        ...          ...
# 7          Vietnam                   PR 2015-10-28            4
# 6          Vietnam                   PR 2015-10-28            4
# 5          Vietnam                   PR 2015-10-28            4
# 8          Vietnam                   PR 2015-10-28            4
# 4          Vietnam                   PR 2015-10-28            4
#
# [264 rows x 4 columns]

# %% [markdown]
# Master Table (versus simply naive method)
# * Median of the last four weeks
# * And fill in with earlier Median if the last four weeks has no data

# %%
# Show the last four weeks of history leading up to the run date, sorted by order_date
history = df[
    (df['order_date'] >= run_date - pd.Timedelta(weeks=4)) &
    (df['order_date'] < run_date)
].sort_values('order_date')
history
# Out:
#     origin_country us_destination_state  projected_days  actual_days  \
# 651        Vietnam                   IL               2            3
# 652        Vietnam                   PR               4            3
# 653        Vietnam                   NC               2            6
# 654        Vietnam                   AZ               1            2
# 655        Vietnam                   PR               4            3
# 656        Vietnam                   PR               4            4
# 657        Vietnam                   FL               4            5
# 658        Vietnam                   CA               4            5
# 659        Vietnam                   OH               4            6
# 660        Vietnam                   CA               4            6
# 661        Vietnam                   PR               4            2
# 662        Vietnam                   MI               4            3
# 663        Vietnam                   PR               4            2
# 665        Vietnam                   PA               4            3
# 664        Vietnam                   PR               4            4
# 666        Vietnam                   CA               4            4
# 667        Vietnam                   FL               4            6
# 668        Vietnam                   PR               4            5
# 669        Vietnam                   CA               2            6
# 670        Vietnam                   PA               1            2
# 671        Vietnam                   PR               4            3
# 672        Vietnam                   PR               0            1
# 673        Vietnam                   PR               2            5
# 674        Vietnam                   IL               4            2
# 678        Vietnam                   PR               2            6
# 675        Vietnam                   CA               1            2
# 676        Vietnam                   TX               1            2
# 677        Vietnam                   PR               2            2
# 679        Vietnam                   TX               4            3
#
#     order_date  order_number
# 651 2017-12-01           652
# 652 2017-12-02           653
# 653 2017-12-04           654
# 654 2017-12-05           655
# 655 2017-12-06           656
# 656 2017-12-07           657
# 657 2017-12-08           658
# 658 2017-12-08           659
# 659 2017-12-09           660
# 660 2017-12-09           661
# 661 2017-12-09           662
# 662 2017-12-10           663
# 663 2017-12-11           664
# 665 2017-12-12           666
# 664 2017-12-12           665
# 666 2017-12-13           667
# 667 2017-12-13           668
# 668 2017-12-14           669
# 669 2017-12-15           670
# 670 2017-12-20           671
# 671 2017-12-21           672
# 672 2017-12-23           673
# 673 2017-12-24           674
# 674 2017-12-24           675
# 678 2017-12-25           679
# 675 2017-12-25           676
# 676 2017-12-25           677
# 677 2017-12-25           678
# 679 2017-12-25           680

# %%
# Keep the median actual_days for each origin_country and us_destination_state combination in the last four weeks of history, and use that as the predicted_days for any rows in the test set that don't have a predicted_days value from the naive model (because they didn't have a matching origin_country and us_destination_state combination in the training set).
master_table = history.groupby(['origin_country', 'us_destination_state'])['actual_days'].median().reset_index()
master_table.rename(columns={'actual_days': 'median_actual_days'}, inplace=True)
master_table
# Out:
#   origin_country us_destination_state  median_actual_days
# 0        Vietnam                   AZ                 2.0
# 1        Vietnam                   CA                 5.0
# 2        Vietnam                   FL                 5.5
# 3        Vietnam                   IL                 2.5
# 4        Vietnam                   MI                 3.0
# 5        Vietnam                   NC                 6.0
# 6        Vietnam                   OH                 6.0
# 7        Vietnam                   PA                 2.5
# 8        Vietnam                   PR                 3.0
# 9        Vietnam                   TX                 2.5

# %%
actuals
# Out:
#    origin_country us_destination_state order_date  order_number  actual_days
# 0         Vietnam                   PR 2017-12-26           681            4
# 1         Vietnam                   PR 2017-12-26           682            3
# 2         Vietnam                   CA 2017-12-26           683            2
# 3         Vietnam                   PR 2017-12-27           684            4
# 4         Vietnam                   PR 2017-12-27           685            3
# 5         Vietnam                   OH 2017-12-28           686            6
# 6         Vietnam                   MD 2017-12-28           687            4
# 7         Vietnam                   OH 2017-12-28           688            4
# 8         Vietnam                   OH 2017-12-29           689            5
# 9         Vietnam                   MO 2017-12-29           690            5
# 10        Vietnam                   PR 2017-12-30           691            6
# 11        Vietnam                   NJ 2017-12-30           692            4
# 12        Vietnam                   PR 2017-12-30           693            6
# 13        Vietnam                   PR 2017-12-31           694            2
# 14        Vietnam                   SC 2017-12-31           695            3
# 15        Vietnam                   PR 2018-01-01           696            4
# 16        Vietnam                   CO 2018-01-02           697            2
# 17        Vietnam                   PR 2018-01-02           698            5
# 18        Vietnam                   FL 2018-01-02           699            4

# %%
# Add the median_actual_days from the master_table to the actuals DataFrame as predicted_days, 
# matching on origin_country and us_destination_state. If there is no match in the master_table for a 
# given origin_country and us_destination_state combination, then predicted_days should be set to None.
md = actuals.merge(master_table, how='left', on=['origin_country', 'us_destination_state'])
md = md.rename(columns={'median_actual_days': 'predicted_days'})
md['predicted_days'] = md['predicted_days'].where(md['predicted_days'].notna(), None)
md
# Out:
#    origin_country us_destination_state order_date  order_number  actual_days  \
# 0         Vietnam                   PR 2017-12-26           681            4
# 1         Vietnam                   PR 2017-12-26           682            3
# 2         Vietnam                   CA 2017-12-26           683            2
# 3         Vietnam                   PR 2017-12-27           684            4
# 4         Vietnam                   PR 2017-12-27           685            3
# 5         Vietnam                   OH 2017-12-28           686            6
# 6         Vietnam                   MD 2017-12-28           687            4
# 7         Vietnam                   OH 2017-12-28           688            4
# 8         Vietnam                   OH 2017-12-29           689            5
# 9         Vietnam                   MO 2017-12-29           690            5
# 10        Vietnam                   PR 2017-12-30           691            6
# 11        Vietnam                   NJ 2017-12-30           692            4
# 12        Vietnam                   PR 2017-12-30           693            6
# 13        Vietnam                   PR 2017-12-31           694            2
# 14        Vietnam                   SC 2017-12-31           695            3
# 15        Vietnam                   PR 2018-01-01           696            4
# 16        Vietnam                   CO 2018-01-02           697            2
# 17        Vietnam                   PR 2018-01-02           698            5
# 18        Vietnam                   FL 2018-01-02           699            4
#
#     predicted_days
# 0              3.0
# 1              3.0
# 2              5.0
# 3              3.0
# 4              3.0
# 5              6.0
# 6              NaN
# 7              6.0
# 8              6.0
# 9              NaN
# 10             3.0
# 11             NaN
# 12             3.0
# 13             3.0
# 14             NaN
# 15             3.0
# 16             NaN
# 17             3.0
# 18             5.5

# %%
# Add in additional rows, from previous runs, for missing origin_country and us_destination_state combinations in the test set

# But for now, just don't predict for those missing combinations
# add the predicted_days column to naive, and fill it with the actual_days for each origin_country and us_destination_state combination in a_train
md = md.dropna().reset_index(drop=True)
md
# Out:
#    origin_country us_destination_state order_date  order_number  actual_days  \
# 0         Vietnam                   PR 2017-12-26           681            4
# 1         Vietnam                   PR 2017-12-26           682            3
# 2         Vietnam                   CA 2017-12-26           683            2
# 3         Vietnam                   PR 2017-12-27           684            4
# 4         Vietnam                   PR 2017-12-27           685            3
# 5         Vietnam                   OH 2017-12-28           686            6
# 6         Vietnam                   OH 2017-12-28           688            4
# 7         Vietnam                   OH 2017-12-29           689            5
# 8         Vietnam                   PR 2017-12-30           691            6
# 9         Vietnam                   PR 2017-12-30           693            6
# 10        Vietnam                   PR 2017-12-31           694            2
# 11        Vietnam                   PR 2018-01-01           696            4
# 12        Vietnam                   PR 2018-01-02           698            5
# 13        Vietnam                   FL 2018-01-02           699            4
#
#     predicted_days
# 0              3.0
# 1              3.0
# 2              5.0
# 3              3.0
# 4              3.0
# 5              6.0
# 6              6.0
# 7              6.0
# 8              3.0
# 9              3.0
# 10             3.0
# 11             3.0
# 12             3.0
# 13             5.5

# %%
# Calculate summary metrics
md_results, md_mape = functions.summarize_results(md, 
                                         run_date, 
                                         y_test=md['actual_days'],
                                         y_pred=md['predicted_days'],
                                         model_name='Master Table',
                                         print_stats=True,
                                         window_days=7)
print('Unique Origin-Destination pairs:',len(md_results[['origin_country', 'us_destination_state']].drop_duplicates()))
md_results
# Out:
# Predicted rows: 14
#  MAE: 1.393
#  RMSE: 1.737
#  R2: -0.782
#  MAPE: 0.373
# Unique Origin-Destination pairs: 4
#    origin_country us_destination_state order_date  order_number  actual  pred  \
# 0         Vietnam                   PR 2017-12-26           681       4   3.0
# 1         Vietnam                   PR 2017-12-26           682       3   3.0
# 2         Vietnam                   CA 2017-12-26           683       2   5.0
# 3         Vietnam                   PR 2017-12-27           684       4   3.0
# 4         Vietnam                   PR 2017-12-27           685       3   3.0
# 5         Vietnam                   OH 2017-12-28           686       6   6.0
# 6         Vietnam                   OH 2017-12-28           688       4   6.0
# 7         Vietnam                   OH 2017-12-29           689       5   6.0
# 8         Vietnam                   PR 2017-12-30           691       6   3.0
# 9         Vietnam                   PR 2017-12-30           693       6   3.0
# 10        Vietnam                   PR 2017-12-31           694       2   3.0
# 11        Vietnam                   PR 2018-01-01           696       4   3.0
# 12        Vietnam                   PR 2018-01-02           698       5   3.0
# 13        Vietnam                   FL 2018-01-02           699       4   5.5
#
#     abs_err         model
# 0       1.0  Master Table
# 1       0.0  Master Table
# 2       3.0  Master Table
# 3       1.0  Master Table
# 4       0.0  Master Table
# 5       0.0  Master Table
# 6       2.0  Master Table
# 7       1.0  Master Table
# 8       3.0  Master Table
# 9       3.0  Master Table
# 10      1.0  Master Table
# 11      1.0  Master Table
# 12      2.0  Master Table
# 13      1.5  Master Table

# %% [markdown]
# Summary
# * This summary can be conducted from a new notebook going forward, which imports the results from each model

# %%
# # append rf_results, n_results, and md_results into a new summary table
# # rf_summary = rf_results.rename(columns={'actual': 'actual_days', 'pred': 'predicted_days'}).drop(columns=['abs_err'])
# # summary = pd.concat([rf_summary, n_results, md_results], ignore_index=True, sort=False)
# summary = pd.concat([n_results, md_results], ignore_index=True, sort=False)
# summary = summary[['origin_country', 'us_destination_state', 'actual_days', 'predicted_days', 'model', 'order_date', 'order_number']]
# summary

# %%
# # How many observations were in the test set for each model?
# summary.groupby('model').count()['actual_days']

# %%
# # Using the df summary, pivot the "model" column such athat each of the values of "model" becomes a separate column, and the values in those columns are the predicted_days. The actual_days column should stay the same.
# summary_pivot = summary.pivot_table(index=['origin_country', 'us_destination_state', 'order_date', 'order_number', 'actual_days',]
#                                     , columns='model'
#                                     , values='predicted_days').reset_index()
# summary_pivot

# %% [markdown]
# Evaluation across multiple time periods (folds) for the Naive Method

# %%
# Choose the run_date for the train-test split
run_date = features_data['order_date'].quantile(0.9)
print(run_date)
# The window of dates will be one week
print(run_date + pd.Timedelta(days=7))

# Create a list of run_dates to loop through
run_dates = pd.date_range(start=run_date, end=features_data["order_date"].max() - pd.Timedelta(days=14), freq='7D')
run_dates
# Out:
# 2017-12-26 00:00:00
# 2018-01-02 00:00:00
# DatetimeIndex(['2017-12-26', '2018-01-02', '2018-01-09', '2018-01-16',
#                '2018-01-23'],
#               dtype='datetime64[us]', freq='7D')

# %%
mape_records = []
for r in run_dates:
    # Get data
    a_train1 = df[df['order_date'] < r]
    a_test1 = df[df['order_date'] >= r]
    a_test = a_test1[a_test1['order_date'] <= r + pd.Timedelta(days=7)]
    actuals = a_test[['origin_country', 'us_destination_state', 'order_date', 'order_number', 'actual_days']].reset_index(drop=True)

    # add the predicted_days column to naive, and fill it with the actual_days for each origin_country and us_destination_state combination in a_train
    naive = actuals.copy()
    naive['predicted_days'] = naive.apply(lambda row: a_train[(a_train['origin_country'] == row['origin_country']) & (a_train['us_destination_state'] == row['us_destination_state'])]['actual_days'].iloc[-1] if not a_train[(a_train['origin_country'] == row['origin_country']) & (a_train['us_destination_state'] == row['us_destination_state'])].empty else None, axis=1)

    # if naive['predicted_days'] is null, remove those rows from the data, we can handle those with a different method (master table) later
    naive = naive.dropna(subset=['predicted_days']).reset_index(drop=True)
    # naive['predicted_days'] = naive['predicted_days'].fillna(a_train['actual_days'].mean())

    # Only run the model if there are rows in the test set for the given run_date
    if(len(a_test) > 0):
        # Testing data dimension columns
        # Run the model
        # Get the predicted values for the test set
        results, mape = functions.summarize_results(naive, 
                                        run_date, 
                                        y_test=naive['actual_days'], 
                                        y_pred=naive['predicted_days'],
                                        model_name='Naive',
                                        print_stats=False,
                                        window_days=7)
        mape_records.append({'run_date': r, 'mape': round(mape, 3)})

n_mape_df = pd.DataFrame(mape_records)
n_mape_df
# Out:
#     run_date          mape
# 0 2017-12-26  4.960000e-01
# 1 2018-01-02  8.600000e-01
# 2 2018-01-09  3.377700e+15
# 3 2018-01-16  1.158000e+00
# 4 2018-01-23  1.054000e+00

# %%
# remove outliers from n_mape_df and average the rest
q_high = n_mape_df['mape'].quantile(0.99)
n_mape_df_filtered = n_mape_df[(n_mape_df['mape'] <= q_high)]
n_mape_avg = n_mape_df_filtered['mape'].mean()
n_mape_avg
# Out:
# np.float64(0.8919999999999999)

# %%
n_mape_df_filtered
# Out:
#     run_date   mape
# 0 2017-12-26  0.496
# 1 2018-01-02  0.860
# 3 2018-01-16  1.158
# 4 2018-01-23  1.054
